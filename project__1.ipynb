# %% [markdown]
# <a href="https://colab.research.google.com/github/MiklRov/MiklRov/blob/main/project__1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Привет! Меня зовут Александр Арасланов, я провожу ревью твоей работы. Предалагю общаться на «ты», если не против.
#
# В работе ты увидишь комментарии, помеченные разным цветом.
#
# <div class="alert alert-danger"> ❌
# Красным цветом помечены моменты, которые необходимо доработать, чтобы проект был принят. Уверен, что у тебя все получится. Буду ждать твою работу на повторное ревью.
# </div>
#
# <div class="alert alert-success"> ✅
# Зеленым цветом помечены оброзцовые решения. Которые можно использовать в дальнейшем.
# </div>
#
# <div class="alert alert-warning"> ⚠️
# Желтым цветом отмечено то, что ты можешь улучшить или доработать. Можешь учесть это при выполнении следующих работ или доработать проект сейчас, но это не обязательно.
# </div>
#
#
# Будет комфортнее работать над проектом вместе, если ты будешь **писать об изменениях** в проекте по моим рекомендациям. Для этого выбери для своих комментариев
#
# <div class="alert alert-block alert-info">заметный цвет</div>
#
# Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# # Сборный проект -1

# %% [markdown]
# ## *Описание проекта*
# Вы работаете в интернет-магазине «Стримчик», который продаёт по всему миру компьютерные игры. Из открытых источников доступны исторические данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation). Вам нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
#
# Перед вами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и вы планируете кампанию на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
#
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# ## *Описание данных*
# Name — название игры
# Platform — платформа
# Year_of_Release — год выпуска
# Genre — жанр игры
# NA_sales — продажи в Северной Америке (миллионы проданных копий)
# EU_sales — продажи в Европе (миллионы проданных копий)
# JP_sales — продажи в Японии (миллионы проданных копий)
# Other_sales — продажи в других странах (миллионы проданных копий)
# Critic_Score — оценка критиков (максимум 100)
# User_Score — оценка пользователей (максимум 10)
# Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ## *Инструкция по выполнению проекта*
# **Шаг 1. Откройте файл с данными и изучите общую информацию**
#
# Путь к файлу: /datasets/games.csv. Скачать датасет
#
# **Шаг 2. Подготовьте данные**
#
# Замените названия столбцов (приведите к нижнему регистру);
# Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# Обработайте пропуски при необходимости:
# Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# Опишите причины, которые могли привести к пропускам;
# Обратите внимание на аббревиатуру 'tbd' в столбце с оценкой пользователей.    Отдельно разберите это значение и опишите, как его обработать;
# Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.
#
# **Шаг 3. Проведите исследовательский анализ данных**
#
# Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# Возьмите данные за соответствующий актуальный период.
# Актуальный период определите самостоятельно в результате исследования предыдущих вопросов.
# Основной фактор — эти данные помогут построить прогноз на 2017 год.
# Не учитывайте в работе данные за предыдущие годы.
# Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# Соотнесите выводы с продажами игр на других платформах.
# Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?
#
# **Шаг 4. Составьте портрет пользователя каждого региона**
#
# Определите для пользователя каждого региона (NA, EU, JP):
# Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# Самые популярные жанры (топ-5). Поясните разницу.
# Влияет ли рейтинг ESRB на продажи в отдельном регионе?
#
# **Шаг 5. Проверьте гипотезы**
#
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
#
# ***Поясните:***
#
# Как вы сформулировали нулевую и альтернативную гипотезы;
# Какой критерий применили для проверки гипотез и почему.
#
# **Шаг 6. Напишите общий вывод**
#
# Оформление: Выполните задание в Jupyter Notebook. Заполните программный код в ячейках типа code, текстовые пояснения — в ячейках типа markdown. Примените форматирование и заголовки.

# %% [markdown]
# ## *Как будут проверять мой проект?*
# Мы подготовили критерии оценки проекта. Прежде чем решать кейс, внимательно изучите их.
# На что обращают внимание при проверке проекта:
# Как вы описываете выявленные в данных проблемы?
# Как готовите датасет к анализу?
# Какие строите графики для распределений и как их объясняете?
# Как рассчитываете стандартное отклонение и дисперсию?
# Формулируете ли альтернативную и нулевую гипотезы?
# Какие методы применяете, чтобы их проверить?
# Объясняете результат проверки гипотезы или нет?
# Соблюдаете ли структуру проекта и поддерживаете аккуратность кода?
# Какие выводы делаете?
# Оставляете ли комментарии к шагам?
# Всё необходимое, чтобы выполнить проект, есть в шпаргалках и конспектах прошлых тем.
#
# *Успехов!*

# %%
import pandas as pd
import numpy as np
import math
from sklearn import datasets
import matplotlib.pyplot as plt
plt.style.use('dark_background')
# %config InlineBackend.figure_format = 'retina'
pd.options.display.float_format = '{:,.2f}'.format
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from scipy import stats as st

# %%
df = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii         2,006.00        Sports     41.36
# 1         Super Mario Bros.      NES         1,985.00      Platform     29.08
# 2            Mario Kart Wii      Wii         2,008.00        Racing     15.68
# 3         Wii Sports Resort      Wii         2,009.00        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB         1,996.00  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45         76.00          8      E
# 1      3.58      6.81         0.77           nan        NaN    NaN
# 2     12.76      3.79         3.29         82.00        8.3      E
# 3     10.93      3.28         2.95         80.00          8      E
# 4      8.89     10.22         1.00           nan        NaN    NaN

# %% [markdown]
# Приведем названия столбцов к нижнему регистру

# %%
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16713 non-null object
# platform           16715 non-null object
# year_of_release    16446 non-null float64
# genre              16713 non-null object
# na_sales           16715 non-null float64
# eu_sales           16715 non-null float64
# jp_sales           16715 non-null float64
# other_sales        16715 non-null float64
# critic_score       8137 non-null float64
# user_score         10014 non-null object
# rating             9949 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %% [markdown]
# Удалим строки с отсутвующим годом, названием и жанром. Так как пропуски в этих столбцах не позволят нам в дальнейшем провести качественный анализ. Их доля не большая и удаление не повлияет на результат

# %%
df.dropna(subset = ['name', 'year_of_release', 'genre'], axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null float64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         9839 non-null object
# rating             9768 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Данные успешно считаны и получены основные сведения о них 👍</div>

# %% [markdown]
# Сменим формат столбца 'year_of_release' на дату

# %%
df['year_of_release'] = df['year_of_release'].astype('int64')
df['year_of_release'] = pd.to_datetime(df['year_of_release'].astype(str), format='%Y')
df['year_of_release'] = df['year_of_release'].dt.year

# %% [markdown]
# Посмотрим на игры с оценки пользователей со значением *tbd*

# %%
df.query('user_score == "tbd"')
# Out:
#                                  name platform  year_of_release       genre  \
# 119                     Zumba Fitness      Wii             2010      Sports
# 301    Namco Museum: 50th Anniversary      PS2             2005        Misc
# 520                   Zumba Fitness 2      Wii             2011      Sports
# 645                      uDraw Studio      Wii             2010        Misc
# 718                   Just Dance Kids      Wii             2010        Misc
# ...                               ...      ...              ...         ...
# 16695                 Planet Monsters      GBA             2001      Action
# 16697                Bust-A-Move 3000       GC             2003      Puzzle
# 16698                Mega Brain Boost       DS             2008      Puzzle
# 16704                        Plushees       DS             2008  Simulation
# 16706   Men in Black II: Alien Escape       GC             2003     Shooter
#
# ...

# %% [markdown]
# Игры старые, врядли уже добавят рейтинг. Заменим на NaN, и сменим формат данных

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Отлично справился с заменой 👍</div>

# %%
df.loc[df['user_score'] == 'tbd', 'user_score'] = float('NaN')
df['user_score'] = df['user_score'].astype('float64')

# %%
df.isna().sum()
# Out:
# name                  0
# platform              0
# year_of_release       0
# genre                 0
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8461
# user_score         8981
# rating             6676
# dtype: int64

# %% [markdown]
# Добавим столбец с суммарными продажами

# %%
df['total_sales'] = df['na_sales'] + df['eu_sales'] + df['jp_sales']+df['other_sales']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 12 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         7463 non-null float64
# rating             9768 non-null object
# total_sales        16444 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# # EDA

# %% [markdown]
# Оценим количество игр выпускавшихся в разные годы

# %%
df.groupby(['year_of_release' ])['name'].agg('nunique')
# Out:
# year_of_release
# 1980       9
# 1981      46
# 1982      36
# 1983      17
# 1984      14
# 1985      14
# 1986      21
# 1987      16
# 1988      15
# 1989      17
# 1990      16
# 1991      40
# 1992      41
# 1993      59
# 1994     117
# 1995     215
# 1996     258
# 1997     282
# 1998     364
# 1999     326
# 2000     325
# 2001     428
# 2002     631
# 2003     546
# 2004     550
# 2005     657
# 2006     773
# 2007     884
# 2008    1039
# 2009    1001
# 2010     900
# 2011     779
# 2012     446
# 2013     335
# 2014     319
# 2015     362
# 2016     297
# Name: name, dtype: int64

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️Комментарий ревьюера**
#
# хм, но одна и та же игра может выпускать на нескольких платформах. Стоит ли это учитывать? вижу, что ты не учитывал. Зависит от вопроса конечно</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %%
plt.figure(figsize=(20,9))
df.groupby(['year_of_release' ])['name'].agg('nunique').plot(kind='bar', grid=True);

plt.xlabel('Год')
plt.title('Количество выпущенных игр по годам')
plt.show()

# %% [markdown]
# Как история эти данные интересны, как данные для построения проноза нет смысла брать такой большой период. Так как сменились платформы, жанры, предпочтения

# %% [markdown]
# <div class="alert alert-warning">
#
# **⚠️Комментарий ревьюера**
#
# Хороший график, но ему стоит дать название, чтобы было однозначно понятно, какой показатель отображен на нем</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %%
top_10 = df.groupby('platform').agg({'total_sales': 'sum'}).sort_values(by = 'total_sales').tail(10).index

# %%
df.query('platform in @top_10').pivot_table(index = 'year_of_release', columns = 'platform', values = 'total_sales', aggfunc = 'sum' ).plot(figsize=(20,9));
plt.xlabel('Год')
plt.title('Количество выпущенных игр по годам и платформам')
plt.show()

# %%
life_cycle = df.groupby('platform').agg({'year_of_release' : ['min', 'max']}).reset_index()
life_cycle.columns= ['platform', "min_year", "max_year"]
life_cycle['year']= life_cycle["max_year"] - life_cycle['min_year']

# %%
life_cycle.query('platform in @top_10')
# Out:
#    platform  min_year  max_year  year
# 2       3DS      2011      2016     5
# 4        DS      1985      2013    28
# 6       GBA      2000      2007     7
# 15       PS      1994      2003     9
# 16      PS2      2000      2011    11
# 17      PS3      2006      2016    10
# 18      PS4      2013      2016     3
# 19      PSP      2004      2015    11
# 26      Wii      2006      2016    10
# 28     X360      2005      2016    11

# %% [markdown]
# Нужно посмотреть потоки по платформам за последние 5ть лет. Уберем 2016 год так как в нем не полные данные и это дает искажение по потокам

# %%
df.query('year_of_release > 2011 and year_of_release <2016').pivot_table(index = 'year_of_release', columns = 'platform', values = 'total_sales', aggfunc = 'sum' ).plot(figsize=(20,9));
plt.xlabel('Год')
plt.title('Количество выпущенных игр по годам и платформам в период 2011 - 2015')
plt.show()

# %%
df.query('year_of_release > 2011').pivot_table(index = 'year_of_release', columns = 'platform', values = 'total_sales', aggfunc = 'sum' )
# Out:
# platform          3DS    DS    PC    PS3    PS4  PSP   PSV   Wii  WiiU  X360  \
# year_of_release
# 2012            51.36 11.01 23.22 107.36    nan 7.69 16.19 21.71 17.56 99.74
# 2013            56.57  1.54 12.38 113.25  25.99 3.14 10.59  8.59 21.65 88.58
# 2014            43.76   nan 13.28  47.76 100.00 0.24 11.90  3.75 22.03 34.74
# 2015            27.78   nan  8.52  16.82 118.90 0.12  6.25  1.14 16.35 11.96
# 2016            15.14   nan  5.25   3.60  69.25  nan  4.25  0.18  4.60  1.52
#
# platform         XOne
# year_of_release
# 2012              nan
# 2013            18.96
# 2014            54.07
# 2015            60.14
# 2016            26.15

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Согласен с определением актуального периода и перспективными платформами 👍</div>

# %% [markdown]
# На основании вышеизложенного видно, что потоки растут на XOne, PS4. На остальных платформах они снижаются. Т.е. эти 2 платформы являются самыми перспективными. PC, 3DS, PSV падение продаж меньшее чем у остальных платформах
# Сделаем дата сет с 5-мя платформами и после 2011 года

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌Комментарий ревьюера**
#
# Если честно, то немного запутался и не понял, почему так резко решил перейти к анализу в детализации по жанрам. Хотя структура проекта согласно брифу должна быть другой. Например, не увидел у тебя бокслоты с продажами по перспективным платформам за актуальный период</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера V2**
#
# Хорошо, бокслоты построил верно 👍 Вижу, что за одно перестроил структуру проекта</div>

# %%
df_clean = df.query('platform == ("XOne", "PS4","PC", "3DS", "PSV") and year_of_release > 2011')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1696 entries, 31 to 16714
# Data columns (total 12 columns):
# name               1696 non-null object
# platform           1696 non-null object
# year_of_release    1696 non-null int64
# genre              1696 non-null object
# na_sales           1696 non-null float64
# eu_sales           1696 non-null float64
# jp_sales           1696 non-null float64
# other_sales        1696 non-null float64
# critic_score       830 non-null float64
# user_score         889 non-null float64
# rating             906 non-null object
# total_sales        1696 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 172.2+ KB

# %%
df_clean.groupby('platform')['total_sales'].describe()
# Out:
#           count  mean  std  min  25%  50%  75%   max
# platform
# 3DS      396.00  0.49 1.39 0.01 0.04 0.11 0.31 14.60
# PC       250.00  0.25 0.49 0.01 0.03 0.08 0.24  5.14
# PS4      392.00  0.80 1.61 0.01 0.06 0.20 0.73 14.63
# PSV      411.00  0.12 0.20 0.01 0.02 0.05 0.12  1.96
# XOne     247.00  0.65 1.04 0.01 0.06 0.22 0.69  7.39

# %%
df_clean.boxplot(column = 'total_sales', by = 'platform',figsize = (20, 9))
plt.xlabel('Название платформы')
plt.ylabel('Доход')
plt.ylim(0, 2)
plt.title('Диаграмма размаха дохода по платформам в период 2011 - 2015')
plt.show()

# %%
df_clean.groupby('platform')['total_sales'].describe()
# Out:
#           count  mean  std  min  25%  50%  75%   max
# platform
# 3DS      396.00  0.49 1.39 0.01 0.04 0.11 0.31 14.60
# PC       250.00  0.25 0.49 0.01 0.03 0.08 0.24  5.14
# PS4      392.00  0.80 1.61 0.01 0.06 0.20 0.73 14.63
# PSV      411.00  0.12 0.20 0.01 0.02 0.05 0.12  1.96
# XOne     247.00  0.65 1.04 0.01 0.06 0.22 0.69  7.39

# %%
df_clean.groupby('platform')['total_sales'].sum()
# Out:
# platform
# 3DS    194.61
# PC      62.65
# PS4    314.14
# PSV     49.18
# XOne   159.32
# Name: total_sales, dtype: float64

# %% [markdown]
# PS4 является лидером по выручке, имея наибольшее среднее и медианное значение. А так же максимальную выручку по одной игре (экслюзивы?)
# На втором месте по объему выручки 3DS. По более низкому среднему и медианному при паритете по количеству игр, можно сделать вывод что большое количество игр не приносит существенного роста выручки, но есть игры которые генерируют большую выручку.
# XOne имея меньшее количество игр, зарабатывает в среднем с каждой игры больше чем 3DS, это видно по среднему и по медианному значению.
# PC занимает 4-е место. PSV входит в топ-5 за счет большого количества игр имея при этом достаточно низкую выручку в расчете на игру

# %% [markdown]
# Посмотрим корреляцию с начала по общим продажам и по регионам, а потом по платформам.

# %%
df_corr = df_clean[['total_sales', 'user_score', 'critic_score', 'na_sales',	'eu_sales',	'jp_sales', 'other_sales']].corr()
df_corr
# Out:
#               total_sales  user_score  critic_score  na_sales  eu_sales  \
# total_sales          1.00       -0.02          0.31      0.92      0.92
# user_score          -0.02        1.00          0.47     -0.03     -0.05
# critic_score         0.31        0.47          1.00      0.31      0.27
# na_sales             0.92       -0.03          0.31      1.00      0.77
# eu_sales             0.92       -0.05          0.27      0.77      1.00
# jp_sales             0.53        0.15          0.10      0.34      0.28
# other_sales          0.90       -0.03          0.28      0.84      0.93
#
#               jp_sales  other_sales
# total_sales       0.53         0.90
# user_score        0.15        -0.03
# critic_score      0.10         0.28
# na_sales          0.34         0.84
# eu_sales          0.28         0.93
# jp_sales          1.00         0.20
# other_sales       0.20         1.00

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌Комментарий ревьюера**
#
# Для матрицы корреляций используют тепловую карту, а не `pairplot`
#
# `pairplot` используется тогда, когда нужо понять распределения нескольких величин и как они связаны друг с другом</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера V2**
#
# Можно так же поиграть с параметрами, чтобы вывести числа на график. Для этого можно поставить `annot=True` и `fmt='.2%'` </div>

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df_corr);

# %% [markdown]
# Посмотрим на корреляцию внутри платформ

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Хороший анализ зависимости продаж и рейтинга. Оси было бы хорошо подписать, иначя смотря только на график не понятно на какой оси какой показатель</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %%
params = ['user_score', 'critic_score']
fig, axes = plt.subplots(5, 2, figsize=(10,30))

for i, platform in enumerate(df_clean['platform'].unique()):
  for j, param in enumerate(params):
    ax = axes[i][j]
    current = df_clean.query('platform == @platform')
    
    ax.scatter(x=current[param], y=current['total_sales'], )
    ax.set_title('Распределение продажи на {} с {}'.format(platform, param))
    ax.set_ylabel('Выручка')
    ax.set_xlabel('Рейтинг')

# %% [markdown]
# На всех платформах и во всех регионах видна зависимость выручки от рейтинга критиков, В Северной Америке более выраженная в Японии менее.
# На пользовательский рейтинг не обращают внимания во всех регионах.

# %% [markdown]
# Посмотрим как соотносятся доходы по жанрам

# %%
df_clean.pivot_table(index = 'year_of_release', columns = 'genre', values = 'total_sales', aggfunc = 'sum' )
# Out:
# genre            Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# year_of_release
# 2012              23.94       1.67      1.29  2.84     12.18    0.96    2.65
# 2013              26.88       3.04      1.81  5.44      7.68    0.86    5.21
# 2014              69.59       3.63      8.40 13.71      6.63    0.24    7.04
# 2015              61.14       6.04      7.08  6.74      0.84    0.70    7.96
# 2016              26.82       3.60      3.31  1.39      2.80    0.01    2.79
#
# genre            Role-Playing  Shooter  Simulation  Sports  Strategy
# year_of_release
# 2012                    22.53     5.40       11.51    4.84      0.96
# 2013                    31.48    19.95        7.28   11.07      3.79
# 2014                    37.46    44.22        5.51   25.66      0.92
# 2015                    35.77    58.27        4.93   30.27      1.85
# 2016                    17.30    37.79        1.89   21.21      1.13

# %%
df_clean.pivot_table(index = 'year_of_release', columns = 'genre', values = 'total_sales', aggfunc = 'sum' ).plot(figsize=(20,9));
plt.xlabel('Год')
plt.ylabel('Доход')

plt.title('Доход по жанрам в период 2011 - 2015')
plt.show()

# %% [markdown]
# По жанрам и платформам

# %%
df_clean.pivot_table(index = ['platform', 'year_of_release'], columns = 'genre', values = 'total_sales', aggfunc = 'sum' )
# Out:
# genre                     Action  Adventure  Fighting  Misc  Platform  Puzzle  \
# platform year_of_release
# 3DS      2012              11.45       0.97      0.25  2.35     10.32    0.93
#          2013              11.98       1.76      0.11  3.25      4.81    0.86
#          2014               3.64       0.88      7.67  1.09      3.21    0.19
#          2015              13.27       0.19      0.40  2.26      0.47    0.68
#          2016               5.15       0.50      0.03  0.50      0.30     nan
# PC       2012               5.88       0.36      0.02  0.02      0.07    0.03
#          2013               1.92       0.12       nan  0.66      0.01     nan
#          2014               2.53       0.05       nan  0.01       nan     nan
#          2015               2.26       0.12      0.05  0.04       nan     nan
#          2016               0.55       0.22      0.05   nan      0.06     nan
# PS4      2013               4.48        nan      0.92  0.42      2.27     nan
# ...

# %%
df_clean.pivot_table(index = ['platform'], columns = 'genre', values = 'total_sales', aggfunc = 'sum' ).plot(figsize=(20,9));

# %%
top_genre = df_clean.groupby('genre').agg({'total_sales': 'sum'}).sort_values(by = 'total_sales').tail(5)

top_genre.sort_values(by='total_sales', ascending=False)
# Out:
#               total_sales
# genre
# Action             208.37
# Shooter            165.63
# Role-Playing       144.54
# Sports              93.05
# Simulation          31.12

# %%
df_clean_genre = df_clean.query('genre == ("Action", "Shooter", "Role-Playing", "Sports", "Simulation")')

# %%
df_clean_genre
# Out:
#                                             name platform  year_of_release  \
# 31                     Call of Duty: Black Ops 3      PS4             2015
# 33                           Pokemon X/Pokemon Y      3DS             2013
# 42                            Grand Theft Auto V      PS4             2014
# 47     Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS             2014
# 73                     Animal Crossing: New Leaf      3DS             2012
# ...                                          ...      ...              ...
# 16677           Aikatsu Stars! My Special Appeal      3DS             2016
# 16680                       Kyoukai no Shirayuki      PSV             2016
# 16692          Metal Gear Solid V: Ground Zeroes       PC             2014
# 16699                      The Longest 5 Minutes      PSV             2016
# 16714                        Winning Post 8 2016      PSV             2016
#
# ...

# %%
df_clean_genre.boxplot(column = 'total_sales', by = 'genre',figsize = (20, 5))
plt.ylim (0, 4)
# Out:
# (0, 4)

# %% [markdown]
# Большой выброс по шутерам.

# %% [markdown]
# ### Портрет пользователя

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌Комментарий ревьюера**
#
# А исследование жанров по регионам должно быть в потрете пользователя. В итоге оно у тебя и здесь и там. Не понимаю, для чего тогда здесь дублировать это?</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %% [markdown]
# Рассмотрим влияние региона на жанры

# %%
df_genre = df.query('year_of_release > 2011')
df_genre
# Out:
#                                 name platform  year_of_release         genre  \
# 16                Grand Theft Auto V      PS3             2013        Action
# 23                Grand Theft Auto V     X360             2013        Action
# 31         Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33               Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34        Call of Duty: Black Ops II      PS3             2012       Shooter
# ...                              ...      ...              ...           ...
# 16703               Strawberry Nauts      PSV             2016     Adventure
# 16707               Aiyoku no Eustia      PSV             2014          Misc
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %%
for d in ('na_sales',	'eu_sales',	'jp_sales'):
  (
      df_genre.pivot_table(index='genre', values=d, aggfunc='sum')
      .sort_values(by=d, ascending=False)
      .head(5)
      .plot(kind='bar', figsize = (20,8), grid=True)
  )
  plt.legend([d])
  plt.xlabel('Жанр')
  plt.ylabel('Выручка')
  plt.title('Объем продаж по топ-5 жанрам')
  plt.show()

# %% [markdown]
# Во всех регионах, кроме Японии лидируют шутеры, в Яплнии - РПГ.
# Подробнее особенности по регионам рассмотрим ниже

# %% [markdown]
# #### Северная америка

# %%
na_total = df_genre.pivot_table(index = 'platform', columns = 'genre', values = 'na_sales', aggfunc = 'sum', margins=True, margins_name='total_sales', fill_value=0)
na_total.sort_values(by=('total_sales'), ascending=False).head(6)
# Out:
# genre        Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# platform
# total_sales  177.84       8.92     19.79 38.19     25.38    1.13   17.22
# X360          45.53       1.93      3.19  9.74      1.24    0.00    3.31
# PS4           32.83       1.95      3.60  3.14      2.45    0.00    2.61
# PS3           39.98       2.22      3.70  3.51      1.90    0.00    2.58
# XOne          21.37       1.27      1.65  4.77      0.51    0.00    4.36
# 3DS           13.76       0.82      3.51  1.70      7.28    0.51    0.12
#
# genre        Role-Playing  Shooter  Simulation  Sports  Strategy  total_sales
# platform
# total_sales         64.00   144.77        7.97   81.53      4.23       590.97
# X360                 6.06    44.70        0.94   22.89      0.52       140.05
# PS4                  9.34    32.66        0.21   19.78      0.17       108.74
# PS3                  7.67    22.31        0.51   18.66      0.34       103.38
# ...

# %%
na_genre = df_genre.pivot_table(index = 'genre', values = 'na_sales', aggfunc = 'sum')
na_genre.sort_values(by=('na_sales'), ascending=False).head(5)
# Out:
#               na_sales
# genre
# Action          177.84
# Shooter         144.77
# Sports           81.53
# Role-Playing     64.00
# Misc             38.19

# %%
na = df_genre.pivot_table(index = 'platform', columns = 'genre', values = 'na_sales', aggfunc = 'sum')
na.plot.bar(figsize=(20,5));

# %% [markdown]
# Лидером среди платформ в Северной Америке является X360. На втором месте идет PS4, далее PS3, XOne и 3DS.
# Топ-5 по жанрам - Action, Shooter, Sports, RPG, Misc

# %% [markdown]
# #### Япония

# %%
jp_total = df_genre.pivot_table(index = 'platform', columns = 'genre', values = 'jp_sales', aggfunc = 'sum', margins=True, margins_name='total_sales', fill_value=0)
jp_total.sort_values(by=('total_sales'), ascending=False).head(6)
# Out:
# genre        Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# platform
# total_sales   52.80       8.24      9.44 12.86      8.63    2.14    2.50
# 3DS           20.51       2.73      2.97  5.36      4.32    1.17    0.00
# PS3           13.95       1.03      3.52  0.78      0.08    0.04    0.73
# PSV            6.71       2.28      0.66  2.29      0.06    0.05    0.10
# PS4            5.90       0.45      0.75  0.42      0.49    0.00    0.26
# WiiU           1.09       0.00      1.01  2.45      3.68    0.22    1.30
#
# genre        Role-Playing  Shooter  Simulation  Sports  Strategy  total_sales
# platform
# total_sales         65.44     9.23       10.41    8.01      2.88       192.58
# 3DS                 38.93     0.07        9.39    1.63      0.71        87.79
# PS3                  6.86     4.02        0.61    2.95      0.72        35.29
# PSV                  7.68     0.11        0.04    0.79      0.27        21.04
# ...

# %%
jp_genre = df_genre.pivot_table(index = 'genre', values = 'jp_sales', aggfunc = 'sum')
jp_genre.sort_values(by=('jp_sales'), ascending=False).head(5)
# Out:
#               jp_sales
# genre
# Role-Playing     65.44
# Action           52.80
# Misc             12.86
# Simulation       10.41
# Fighting          9.44

# %%
jp = df_genre.pivot_table(index = 'platform', columns = 'genre', values = 'jp_sales', aggfunc = 'sum', fill_value=0 )
jp.plot.bar(figsize=(20,5));

# %% [markdown]
# В Японии лидером является 3DS. На втором месте идет PS3 и на 3-м PS4.
# Весь ТОП-5 из состоит из японских платформ.
# По жанрам лидирует RPG, за ней идут Action, Misc, Simulation, Fighting

# %% [markdown]
# #### Европа

# %%
eu_total = df_genre.pivot_table(index = 'platform', columns = 'genre', values = 'eu_sales', aggfunc = 'sum', margins=True, margins_name='total_sales', fill_value=0)
eu_total.sort_values(by=('total_sales'), ascending=False).head(6)
# Out:
# genre        Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# platform
# total_sales  159.34       9.46     10.79 26.32     21.41    1.40   27.29
# PS4           42.71       3.00      2.97  3.35      3.60    0.02    7.45
# PS3           43.63       2.02      2.58  3.26      1.63    0.00    6.26
# X360          28.40       1.04      1.21  3.74      0.70    0.00    4.27
# XOne          12.58       1.17      0.54  2.00      0.34    0.00    4.58
# 3DS            9.19       0.61      1.47  2.08      6.26    0.87    0.14
#
# genre        Role-Playing  Shooter  Simulation  Sports  Strategy  total_sales
# platform
# total_sales         48.53   113.47       14.55   69.09      5.17       506.82
# PS4                 11.96    39.16        0.68   25.98      0.21       141.09
# PS3                  5.49    24.56        0.48   16.58      0.37       106.86
# X360                 2.79    21.29        0.41   10.36      0.31        74.52
# ...

# %%
eu_genre = df_genre.pivot_table(index = 'genre', values = 'eu_sales', aggfunc = 'sum')
eu_genre.sort_values(by=('eu_sales'), ascending=False).head(5)
# Out:
#               eu_sales
# genre
# Action          159.34
# Shooter         113.47
# Sports           69.09
# Role-Playing     48.53
# Racing           27.29

# %%
eu = df_genre.pivot_table(index = 'platform', columns = 'genre', values = 'eu_sales', aggfunc = 'sum')
eu.plot.bar(figsize=(20,5));

# %% [markdown]
# В Европе лидирует с большим отрывом PS4. На 2-м месте PS3. На 3-м месте X360.
# По жанрам лидирует Action, далее Shooter, Sport, RPG, Racing

# %%
report = df_genre.groupby('platform')[['na_sales', 'eu_sales', 'jp_sales', 'total_sales']].sum()
display(report.sort_values(by=('total_sales'), ascending=False).head(8))
for col in report.columns:
  report[col] = report[col] / report[col].sum()
display(report.sort_values(by=('total_sales'), ascending=False).head(8))
report.sort_values(by=('total_sales'), ascending=False).head(8).T.plot(kind='bar', stacked = True, figsize=(20,9));
plt.title('Доли платформ по регионам')
plt.ylabel('Доля')
plt.xlabel('Регион');
# Out:
#           na_sales  eu_sales  jp_sales  total_sales
# platform
# PS4         108.74    141.09     15.96       314.14
# PS3         103.38    106.86     35.29       288.79
# X360        140.05     74.52      1.57       236.54
# 3DS          55.31     42.64     87.79       194.61
# XOne         93.12     51.59      0.34       159.32
# WiiU         38.10     25.13     13.01        82.19
# PC           19.12     37.76      0.00        62.65
# PSV          10.98     11.36     21.04        49.18
#           na_sales  eu_sales  jp_sales  total_sales
# platform
# PS4           0.18      0.28      0.08         0.22
# PS3           0.17      0.21      0.18         0.20
# X360          0.24      0.15      0.01         0.16
# 3DS           0.09      0.08      0.46         0.13
# XOne          0.16      0.10      0.00         0.11
# WiiU          0.06      0.05      0.07         0.06
# PC            0.03      0.07      0.00         0.04
# PSV           0.02      0.02      0.11         0.03

# %%
report = df_genre.groupby('genre')[['na_sales', 'eu_sales', 'jp_sales', 'total_sales']].sum().sort_values(by=[col], ascending=False).head(10)
display(report)
for col in report.columns:
  report[col] = report[col] / report[col].sum() *100
display(report)
report.sort_values(by=('total_sales'), ascending=False).head(8).T.plot(kind='bar', stacked = True, figsize=(20,9));
plt.title('Доли жанра по регионам')
plt.ylabel('Доля')
plt.xlabel('Регион');
# Out:
#               na_sales  eu_sales  jp_sales  total_sales
# genre
# Action          177.84    159.34     52.80       441.12
# Shooter         144.77    113.47      9.23       304.73
# Role-Playing     64.00     48.53     65.44       192.80
# Sports           81.53     69.09      8.01       181.07
# Misc             38.19     26.32     12.86        85.04
# Platform         25.38     21.41      8.63        61.00
# Racing           17.22     27.29      2.50        53.50
# Fighting         19.79     10.79      9.44        44.49
# Simulation        7.97     14.55     10.41        35.12
# Adventure         8.92      9.46      8.24        29.43
#               na_sales  eu_sales  jp_sales  total_sales
# genre
# Action           30.37     31.85     28.15        30.88
# Shooter          24.72     22.68      4.92        21.34
# Role-Playing     10.93      9.70     34.89        13.50
# Sports           13.92     13.81      4.27        12.68
# ...

# %% [markdown]
# ### Вывод по регионам
# По платформам:
# 1. PS3, PS4 и 3DS входят в ТОП-5 платформ во всех регионах.
# 2. В Японии доминировании 3DS более чем в 2 раза от ближайшей PS3, в Европе на 1-м месте PS4, в Северной Америке - X360
# 3. Суммарно во всех регионах лидирует - PS4
# По жанрам

# %% [markdown]
# По жанрам:
# 1. Европа и Севреная Америка приоритет по жанрам похож - Экшен, шутер, РПГ, Спорт. Отличие на десятые доли процента в 5-м месте. В Европе - это гонки, а в США - Misc
# 2. Япония лидирует РПГ, потом идут Action, Misc, Simulation, Fighting

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌Комментарий ревьюера**
#
# хм, по сути здесь необходимо было найти свой топ 5 платформ и жанров в каждом регионе. Они могут отличаться. Жанр, который входит в топ 5 в Японии, может не входить в топ 5 по остальным регионам, а ты этого не увидишь. Во вторых стоит рассматривать не только те перспективные платформы, которые ты выбрал, а все, которые есть в актуальном периоде</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Исправил</div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера V2**
#
# Отлично, исправления принял 👍😉 </div>

# %% [markdown]
# Распределение рейтинга ESRB по регионам

# %%
for d in ('na_sales',	'eu_sales',	'jp_sales'):
  (
      df_genre.pivot_table(index='rating', values=d, aggfunc='sum')
      .sort_values(by=d, ascending=False)
      .head(5)
      .plot(kind='bar', figsize = (8,5), grid=True)
  )
  plt.title('Гистограмма распределения влияния рейтинга ESRB на продажи по региону {}'.format(d))
  plt.legend([d])
  plt.xlabel('Рейтинг')
  plt.show()

# %% [markdown]
# Так же как отчлияаются жанры по регионам видно как отличается рейтинг ESRB.
# Игры для взрослых преобладают в Европе и Америке с большим отрывом. В Японии игры для подростков и игры для всех преобладают над остальными

# %% [markdown]
# # Статистический анализ

# %% [markdown]
# ## Гипотеза 1
# Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# H0 - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые
# H1 - Средние пользовательские рейтинги платформ Xbox One и PC различаются

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Гипотезы сформулировал верно, молодец</div>

# %%
df_clean = df_clean.dropna(subset=['user_score'])

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 889 entries, 42 to 16692
# Data columns (total 12 columns):
# name               889 non-null object
# platform           889 non-null object
# year_of_release    889 non-null int64
# genre              889 non-null object
# na_sales           889 non-null float64
# eu_sales           889 non-null float64
# jp_sales           889 non-null float64
# other_sales        889 non-null float64
# critic_score       817 non-null float64
# user_score         889 non-null float64
# rating             848 non-null object
# total_sales        889 non-null float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 90.3+ KB

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Было бы хорошо еще проверить дисперсии распределением и при необходимости использовать параметр `equal_var=False` при проверке гипотезы.</div>

# %%
alpha = .05  
results = st.ttest_ind(
    df_clean.query('platform == "XOne"')['user_score'], 
    df_clean.query('platform == "PC"')['user_score']
    )
 
print('p-значение: ', results.pvalue)
 
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  0.5535080500643661
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# Получено статистически ничтожное различие между выборками, поэтому не отвергаем нулевую гипотезу

# %% [markdown]
# ## Гипотеза 2
# Средние пользовательские рейтинги жанров Action и Sports разные
# H0 - Средние пользовательские рейтинги жанров Action и Sports одинаковые
# H1 - Средние пользовательские рейтинги жанров Action и Sports разные

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера**
#
# Молодец, гипоетзы сформулировал верно.
#
# Было бы хорошо еще проверить дисперсии распределением и при необходимости использовать параметр `equal_var=False` при проверке гипотезы.</div>

# %%
alpha = .05  
results = st.ttest_ind(
    df_clean.query('genre == "Action"')['user_score'], 
    df_clean.query('genre == "Sports"')['user_score']
    )
 
print('p-значение: ', results.pvalue)
 
if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  2.458680543362664e-13
# Отвергаем нулевую гипотезу

# %% [markdown]
# Получено статистически важное различие между выборками, поэтому отвергаем нулевую гипотезу

# %% [markdown]
# # Итоговый вывод

# %% [markdown]
# На основании представленных данных можно сделать следующие выводы
# По платформам:
# 1. PS3, PS4 и 3DS входят в ТОП-5 платформ во всех регионах.
# 2. В Японии доминировании 3DS более чем в 2 раза от ближайшей PS3, в Европе на 1-м месте PS4, в Северной Америке - X360
# 3. Суммарно во всех регионах лидирует - PS4
# По жанрам
# 1. Европа и Севреная Америка приоритет по жанрам похож - Экшен, шутер, РПГ, Спорт. Отличие на десятые доли процента в 5-м месте. В Европе - это гонки, а в США - Misc
# 2. Япония лидирует РПГ, потом идут Action, Misc, Simulation, Fighting
#
# По реитингу ESRB так же есть отличия
# Игры для взрослых преобладают в Европе и Америке с большим отрывом. В Японии игры для подростков и игры для всех преобладают над остальными
#
# Пользователи больше ориентируются на рейтинги критиков, чем на пользовательский рейтинг.
# Преобладают игры на приставках - стационарных в Европе и Америке, портативных в Японии. PC так же удерживает рынок в Европе и Америке, но не используется как игровая платформа в Японии.
#
# 1. Перспективными платформами являются - PS4, XOne, 3DS, PC, PSV.
# Необходимо учитывать регион продаж.
# 2. Перспективные жанры имеют более выраженную терреториальную разницу.
# Для Европы и Америки - Action, Shooter, Sport. Япония - RPG, Fighting, Misc

# %% [markdown]
# <div class="alert alert-danger">
#
# **❌Комментарий ревьюера**
#
# Михаил, ты молодец, хорошо справился с проектом. Успешно подготовил данные, провел хорошее исследование. Есть несколько небольших замечаний и рекомендаций, которые помогут тебе его доработать. Пожалуйста, внеси изменения и присылай работу на повторную проверку.
#
# Общий выводу стоит дополнить. Как минимум можно написать про полуенные портеты пользователей. Про зависиомсти от оценки критиков или пользователей. </div>

# %% [markdown]
# <div class="alert alert-success">
#
# **✅Комментарий ревьюера V2**
#
# Успешно справился со всеми доработками 👍 Вижу, что вопросов нет, проект принимаю, успехов тебе в дальнейшей учебе</div>
